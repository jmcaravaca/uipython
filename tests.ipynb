# %%
from loguru import logger
from config.uipapiconfig import (
    uipclient_folders,
    uipclient_libraries
)
import os

#Update token as needed
fols = uipclient_folders.folders_get()
print(fols)
libs = uipclient_libraries.libraries_get()
# Out:
# {'value': [{'description': 'Carpeta para procesos corporativos',
#             'display_name': '00. Corporativo',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo',
#             'id': 61517,
#             'is_personal': None,
#             'key': '84ee423e-9b59-4f4c-9947-577956988d96',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos de España',
#             'display_name': '01. España',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España',
#             'id': 61518,
#             'is_personal': None,
#             'key': 'bd1ca2d8-cd3c-4473-9fc4-45ff6aafce61',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos Portugal',
#             'display_name': '02. Portugal',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/02. Portugal',
#             'id': 61520,
#             'is_personal': None,
#             'key': '1364129a-d46d-4558-97ca-a1189aeb43f3',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos Brasil',
#             'display_name': '03. Brasil',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/03. Brasil',
#             'id': 61521,
#             'is_personal': None,
#             'key': 'ebfb5105-9a6c-495b-8872-d15ed20b7bff',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos Argentina',
#             'display_name': '05. Argentina',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/05. Argentina',
#             'id': 61522,
#             'is_personal': None,
#             'key': '1b626a73-04aa-489f-a3f7-7a40bfdd3041',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos Chile',
#             'display_name': '06. Chile',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/06. Chile',
#             'id': 61523,
#             'is_personal': None,
#             'key': 'd453421f-f741-4bdd-bccc-a1369c9a6a55',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos Uruguay',
#             'display_name': '07. Uruguay',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/07. Uruguay',
#             'id': 61524,
#             'is_personal': None,
#             'key': '8f1f5f80-81ed-40c9-824f-6eabedb7b40f',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos Colombia',
#             'display_name': '08. Colombia',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/08. Colombia',
#             'id': 61526,
#             'is_personal': None,
#             'key': '642482c7-6ba6-4001-b14c-4974872a8fa8',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos Perú',
#             'display_name': '09. Peru',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/09. Peru',
#             'id': 61527,
#             'is_personal': None,
#             'key': '916ab7f4-b7de-49c9-84ab-5fd6fbe2bcd1',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos México',
#             'display_name': '04. Mexico',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico',
#             'id': 61528,
#             'is_personal': None,
#             'key': '076548d7-5be8-44fe-bcba-d783ba5da359',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para procesos Venezuela',
#             'display_name': '10. Venezuela',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/10. Venezuela',
#             'id': 61529,
#             'is_personal': None,
#             'key': '9de5c41c-2d17-4353-8e86-5f9916f68ff6',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de Operaciones',
#             'display_name': '01. Operaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/05. Argentina/01. Operaciones',
#             'id': 61531,
#             'is_personal': None,
#             'key': '947afa4a-db85-449d-8d55-5e8ddf5cc232',
#             'parent_id': 61522,
#             'parent_key': '1b626a73-04aa-489f-a3f7-7a40bfdd3041',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de Operaciones',
#             'display_name': '01. Operaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/06. Chile/01. Operaciones',
#             'id': 61532,
#             'is_personal': None,
#             'key': '4b373809-1bd6-4bb9-9713-f54038acb91c',
#             'parent_id': 61523,
#             'parent_key': 'd453421f-f741-4bdd-bccc-a1369c9a6a55',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta Proceso Descarga de Notificaciones',
#             'display_name': 'CL002_OPE_DDN_DescargaDeNotificaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/06. Chile/01. '
#                                     'Operaciones/CL002_OPE_DDN_DescargaDeNotificaciones',
#             'id': 61533,
#             'is_personal': None,
#             'key': '8bd8a5b9-8630-4772-987d-f14b75019d43',
#             'parent_id': 61532,
#             'parent_key': '4b373809-1bd6-4bb9-9713-f54038acb91c',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de Operaciones',
#             'display_name': '01. Operaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España/01. Operaciones',
#             'id': 61537,
#             'is_personal': None,
#             'key': '27a94834-663b-4866-b6c5-f26b7b948998',
#             'parent_id': 61518,
#             'parent_key': 'bd1ca2d8-cd3c-4473-9fc4-45ff6aafce61',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'ES002_OPE_MIN_MarcaInternacional',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España/01. '
#                                     'Operaciones/ES002_OPE_MIN_MarcaInternacional',
#             'id': 61538,
#             'is_personal': None,
#             'key': 'ab8793bb-72f9-4de2-986f-f9bac96a3242',
#             'parent_id': 61537,
#             'parent_key': '27a94834-663b-4866-b6c5-f26b7b948998',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta del proceso Renovación de Marcas',
#             'display_name': 'AR001_OPE_RDM_RenovacionDeMarcas',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/05. Argentina/01. '
#                                     'Operaciones/AR001_OPE_RDM_RenovacionDeMarcas',
#             'id': 61539,
#             'is_personal': None,
#             'key': '7dbdf0ff-4311-4c31-a48f-fdcda36ad018',
#             'parent_id': 61531,
#             'parent_key': '947afa4a-db85-449d-8d55-5e8ddf5cc232',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta del Proceso Escritorios RPA',
#             'display_name': 'CL001_OPE_ESC_EscritoriosRPA',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/06. Chile/01. '
#                                     'Operaciones/CL001_OPE_ESC_EscritoriosRPA',
#             'id': 61540,
#             'is_personal': None,
#             'key': '4afa7e7f-99c5-477a-b380-644bf37c654d',
#             'parent_id': 61532,
#             'parent_key': '4b373809-1bd6-4bb9-9713-f54038acb91c',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de Operaciones',
#             'display_name': '01. Operaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/01. Operaciones',
#             'id': 61541,
#             'is_personal': None,
#             'key': '5d71c7a1-a007-454e-8efd-831e1dd936bd',
#             'parent_id': 61528,
#             'parent_key': '076548d7-5be8-44fe-bcba-d783ba5da359',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta del Proceso Notificaciones Pase Impi',
#             'display_name': 'MX001_OPE_NPI_NotificacionPaseImpi',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/01. '
#                                     'Operaciones/MX001_OPE_NPI_NotificacionPaseImpi',
#             'id': 61542,
#             'is_personal': None,
#             'key': '1d53e721-466c-4c64-8234-050c1c0fbb8c',
#             'parent_id': 61541,
#             'parent_key': '5d71c7a1-a007-454e-8efd-831e1dd936bd',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta del proceso Archivados Sharepoint',
#             'display_name': 'MX002_OPE_ASP_ArchivadosSP',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/01. '
#                                     'Operaciones/MX002_OPE_ASP_ArchivadosSP',
#             'id': 61543,
#             'is_personal': None,
#             'key': 'e97a39d2-b0cb-4e40-9179-4e69dbd053d8',
#             'parent_id': 61541,
#             'parent_key': '5d71c7a1-a007-454e-8efd-831e1dd936bd',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de Operaciones',
#             'display_name': '01. Operaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/09. Peru/01. Operaciones',
#             'id': 61544,
#             'is_personal': None,
#             'key': '22d3bf1b-1860-4837-953f-2cf86bfd3119',
#             'parent_id': 61527,
#             'parent_key': '916ab7f4-b7de-49c9-84ab-5fd6fbe2bcd1',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta del proyecto de Automatización de '
#                            'Notificaciones',
#             'display_name': 'PE001_OPE_ADN_AutomatizacionDeNotificaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/09. Peru/01. '
#                                     'Operaciones/PE001_OPE_ADN_AutomatizacionDeNotificaciones',
#             'id': 61547,
#             'is_personal': None,
#             'key': 'c391f60d-4ce5-4b87-920c-6b7b683f7e4f',
#             'parent_id': 61544,
#             'parent_key': '22d3bf1b-1860-4837-953f-2cf86bfd3119',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de CSC Financiero',
#             'display_name': '02. CSC Financiero',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/02. CSC Financiero',
#             'id': 61548,
#             'is_personal': None,
#             'key': '0fe3d8d8-fb3a-44cb-b35e-e8416417de9f',
#             'parent_id': 61528,
#             'parent_key': '076548d7-5be8-44fe-bcba-d783ba5da359',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de People',
#             'display_name': '03. People',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/03. People',
#             'id': 61549,
#             'is_personal': None,
#             'key': '99ea84c1-6176-46d8-b07f-0cd809bdea64',
#             'parent_id': 61517,
#             'parent_key': '84ee423e-9b59-4f4c-9947-577956988d96',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de Financiero',
#             'display_name': '04. Financiero',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/04. Financiero',
#             'id': 61550,
#             'is_personal': None,
#             'key': '07719be8-6ef5-450a-a065-6098655ecce9',
#             'parent_id': 61517,
#             'parent_key': '84ee423e-9b59-4f4c-9947-577956988d96',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de Transformación',
#             'display_name': '05. CTO',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/05. CTO',
#             'id': 61551,
#             'is_personal': None,
#             'key': 'fe2bd7dd-4de6-4f15-99f1-6fd2b6b038ec',
#             'parent_id': 61517,
#             'parent_key': '84ee423e-9b59-4f4c-9947-577956988d96',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de Legal',
#             'display_name': '06. CLO',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/06. CLO',
#             'id': 61552,
#             'is_personal': None,
#             'key': 'd7bee08d-56ca-4f5a-93be-12c1127da381',
#             'parent_id': 61517,
#             'parent_key': '84ee423e-9b59-4f4c-9947-577956988d96',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Procesos del departamento de Revenue',
#             'display_name': '07. CRO',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/07. CRO',
#             'id': 61553,
#             'is_personal': None,
#             'key': 'a41ffdbb-925b-433a-aaf1-6bf69b8b3759',
#             'parent_id': 61517,
#             'parent_key': '84ee423e-9b59-4f4c-9947-577956988d96',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta Para Procesos RPA del CoE de ClarkeModet',
#             'display_name': 'RPA CoE',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE',
#             'id': 61609,
#             'is_personal': None,
#             'key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'parent_id': None,
#             'parent_key': None,
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta para proceso Extractos',
#             'display_name': 'CO002_FIN_EDF_Extractos',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/04. '
#                                     'Financiero/CO002_FIN_EDF_Extractos',
#             'id': 62685,
#             'is_personal': None,
#             'key': '1d4483aa-f631-4cd0-85f2-b6010d8068ce',
#             'parent_id': 61550,
#             'parent_key': '07719be8-6ef5-450a-a065-6098655ecce9',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'ESP001_OPE_COM_ComunicacionesEUIPO',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España/01. '
#                                     'Operaciones/ESP001_OPE_COM_ComunicacionesEUIPO',
#             'id': 66638,
#             'is_personal': None,
#             'key': 'bf8c7ed7-8d1a-4ef9-aef3-35a7f3826ace',
#             'parent_id': 61537,
#             'parent_key': '27a94834-663b-4866-b6c5-f26b7b948998',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'Test',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/Test',
#             'id': 69492,
#             'is_personal': None,
#             'key': '93a77ecb-0e6e-4762-886a-aa0c4a5bde93',
#             'parent_id': 61609,
#             'parent_key': '91b790f7-0b9b-406a-a3fb-5b9b18971678',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta de proceso de altas de empleado',
#             'display_name': 'CO001_CTO_ADE_AltaDeEmpleado',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/05. '
#                                     'CTO/CO001_CTO_ADE_AltaDeEmpleado',
#             'id': 69777,
#             'is_personal': None,
#             'key': 'e35b4c3d-48c3-433a-8232-7b24286bce44',
#             'parent_id': 61551,
#             'parent_key': 'fe2bd7dd-4de6-4f15-99f1-6fd2b6b038ec',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Carpeta Proceso Descarga de Comprobantes',
#             'display_name': 'MX003_OPE_DDC_DescargaDeComprobantes',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/01. '
#                                     'Operaciones/MX003_OPE_DDC_DescargaDeComprobantes',
#             'id': 70535,
#             'is_personal': None,
#             'key': '80468f39-712d-42fe-b95e-8dd91fd55d9d',
#             'parent_id': 61541,
#             'parent_key': '5d71c7a1-a007-454e-8efd-831e1dd936bd',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Proceso para el pago de tasas de indecopi',
#             'display_name': 'PE002_OPE_PTI_PagoTasasIndecopi',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/09. Peru/01. '
#                                     'Operaciones/PE002_OPE_PTI_PagoTasasIndecopi',
#             'id': 74682,
#             'is_personal': None,
#             'key': '9dfbca4b-3251-4373-ad1b-3e874fc58b61',
#             'parent_id': 61544,
#             'parent_key': '22d3bf1b-1860-4837-953f-2cf86bfd3119',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': '01. Operaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/03. Brasil/01. Operaciones',
#             'id': 756489,
#             'is_personal': None,
#             'key': '81f7548a-92b2-4c15-b142-cbd56b8139ea',
#             'parent_id': 61521,
#             'parent_key': 'ebfb5105-9a6c-495b-8872-d15ed20b7bff',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'BR001_OPE_DCT_DescargaComprobantesTasas',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/03. Brasil/01. '
#                                     'Operaciones/BR001_OPE_DCT_DescargaComprobantesTasas',
#             'id': 756490,
#             'is_personal': None,
#             'key': '62ddec95-81d7-4c61-8c0f-b14cd6b86f30',
#             'parent_id': 756489,
#             'parent_key': '81f7548a-92b2-4c15-b142-cbd56b8139ea',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Queue for ARRPA',
#             'display_name': 'AR002_OPE_RPA_RevisionPublicacionActo',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/05. Argentina/01. '
#                                     'Operaciones/AR002_OPE_RPA_RevisionPublicacionActo',
#             'id': 790799,
#             'is_personal': None,
#             'key': '83cf40e7-7c7a-4e1e-8e2e-3c7f17576136',
#             'parent_id': 61531,
#             'parent_key': '947afa4a-db85-449d-8d55-5e8ddf5cc232',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'MX004_OPE_DPI_DescargaPatentesImpi_Escritos',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/01. '
#                                     'Operaciones/MX004_OPE_DPI_DescargaPatentesImpi_Escritos',
#             'id': 798125,
#             'is_personal': None,
#             'key': '8653274e-d50e-4b08-a48e-e5dd404af9cb',
#             'parent_id': 61541,
#             'parent_key': '5d71c7a1-a007-454e-8efd-831e1dd936bd',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'CO005_FIN_EIF_ExtractoInternacionalFacturas',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/04. '
#                                     'Financiero/CO005_FIN_EIF_ExtractoInternacionalFacturas',
#             'id': 798127,
#             'is_personal': None,
#             'key': '82ba108a-f3b1-4c1c-9343-a25ee92a8341',
#             'parent_id': 61550,
#             'parent_key': '07719be8-6ef5-450a-a065-6098655ecce9',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'CL003_OPE_IDE_IncorporacionDeExpedientes',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/06. Chile/01. '
#                                     'Operaciones/CL003_OPE_IDE_IncorporacionDeExpedientes',
#             'id': 801108,
#             'is_personal': None,
#             'key': '717b5879-38e4-4e72-ab77-8d369a1b6794',
#             'parent_id': 61532,
#             'parent_key': '4b373809-1bd6-4bb9-9713-f54038acb91c',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'ES005_OPE_GTR_GestionDeTitulosRenovacion',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España/01. '
#                                     'Operaciones/ES005_OPE_GTR_GestionDeTitulosRenovacion',
#             'id': 801109,
#             'is_personal': None,
#             'key': 'd38e2f8f-42cf-4705-9d58-c67c58c96387',
#             'parent_id': 61537,
#             'parent_key': '27a94834-663b-4866-b6c5-f26b7b948998',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'PE003_OPE_GDT_GestionTitulosPeru',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/09. Peru/01. '
#                                     'Operaciones/PE003_OPE_GDT_GestionTitulosPeru',
#             'id': 801225,
#             'is_personal': None,
#             'key': 'bea0b152-be90-4668-8ec9-7123900d58dd',
#             'parent_id': 61544,
#             'parent_key': '22d3bf1b-1860-4837-953f-2cf86bfd3119',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'CO003_CTO_BDE_BajaDeEmpleado',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/05. '
#                                     'CTO/CO003_CTO_BDE_BajaDeEmpleado',
#             'id': 803795,
#             'is_personal': None,
#             'key': '5985c6fa-afbf-43f0-a4e7-ef8671b7285c',
#             'parent_id': 61551,
#             'parent_key': 'fe2bd7dd-4de6-4f15-99f1-6fd2b6b038ec',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Dory - vía Marcas',
#             'display_name': 'MX005_OPE_DMI_DescargaMarcasImpi',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/01. '
#                                     'Operaciones/MX005_OPE_DMI_DescargaMarcasImpi',
#             'id': 805595,
#             'is_personal': None,
#             'key': '7dbdeba1-500f-4f88-9f05-3923b8ed5beb',
#             'parent_id': 61541,
#             'parent_key': '5d71c7a1-a007-454e-8efd-831e1dd936bd',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'BR005_OPE_PDP_PublicacionDePatentes',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/03. Brasil/01. '
#                                     'Operaciones/BR005_OPE_PDP_PublicacionDePatentes',
#             'id': 808296,
#             'is_personal': None,
#             'key': '0a4208e3-5773-4ace-9f46-003f11f2b6a2',
#             'parent_id': 756489,
#             'parent_key': '81f7548a-92b2-4c15-b142-cbd56b8139ea',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': '01. Operaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/01. Operaciones',
#             'id': 880909,
#             'is_personal': None,
#             'key': '22e6d2e9-bab6-4850-9b24-c459cbe340d2',
#             'parent_id': 61517,
#             'parent_key': '84ee423e-9b59-4f4c-9947-577956988d96',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Valentina',
#             'display_name': 'ES003_OPE_VCA_VolcadoComprobantesAnualidades',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España/01. '
#                                     'Operaciones/ES003_OPE_VCA_VolcadoComprobantesAnualidades',
#             'id': 880994,
#             'is_personal': None,
#             'key': '4ee31760-bccb-4319-88cd-b7b4781c2eeb',
#             'parent_id': 61537,
#             'parent_key': '27a94834-663b-4866-b6c5-f26b7b948998',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Bajas Definitivas',
#             'display_name': 'CO004_CTO_BDF_BajasDefinitivas',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/05. '
#                                     'CTO/CO004_CTO_BDF_BajasDefinitivas',
#             'id': 881779,
#             'is_personal': None,
#             'key': 'e6d98bd0-25e4-4f67-86c4-e0f7790a8b19',
#             'parent_id': 61551,
#             'parent_key': 'fe2bd7dd-4de6-4f15-99f1-6fd2b6b038ec',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'BR002_OPE_DDT_DescargaTitulos',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/03. Brasil/01. '
#                                     'Operaciones/BR002_OPE_DDT_DescargaTitulos',
#             'id': 886611,
#             'is_personal': None,
#             'key': '7d7375b2-0677-4e63-981d-398dc4ceaefd',
#             'parent_id': 756489,
#             'parent_key': '81f7548a-92b2-4c15-b142-cbd56b8139ea',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'ES004_OPE_GTP_GestiónTítulosPatentes',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España/01. '
#                                     'Operaciones/ES004_OPE_GTP_GestiónTítulosPatentes',
#             'id': 893819,
#             'is_personal': None,
#             'key': '94f02c7d-26b6-4163-956c-a54f9f4b6c44',
#             'parent_id': 61537,
#             'parent_key': '27a94834-663b-4866-b6c5-f26b7b948998',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'BR003_OPE_RTP_RevisionTitulosPatentes',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/03. Brasil/01. '
#                                     'Operaciones/BR003_OPE_RTP_RevisionTitulosPatentes',
#             'id': 897053,
#             'is_personal': None,
#             'key': 'ddacbe5b-91fb-4715-a002-60501578826f',
#             'parent_id': 756489,
#             'parent_key': '81f7548a-92b2-4c15-b142-cbd56b8139ea',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Rita II',
#             'display_name': 'BR004_OPE_RTM_RevisiónTitulosMarcas',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/03. Brasil/01. '
#                                     'Operaciones/BR004_OPE_RTM_RevisiónTitulosMarcas',
#             'id': 897065,
#             'is_personal': None,
#             'key': '30f38e59-9b3a-4162-810b-ffe875c2d246',
#             'parent_id': 756489,
#             'parent_key': '81f7548a-92b2-4c15-b142-cbd56b8139ea',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': '01. Operaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/07. Uruguay/01. Operaciones',
#             'id': 898489,
#             'is_personal': None,
#             'key': '899ea7d3-63ec-40f3-b7f8-4b37be6f5dca',
#             'parent_id': 61524,
#             'parent_key': '8f1f5f80-81ed-40c9-824f-6eabedb7b40f',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'UR001_OPE_NDB_NotificacionesDeBoletin',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/07. Uruguay/01. '
#                                     'Operaciones/UR001_OPE_NDB_NotificacionesDeBoletin',
#             'id': 898490,
#             'is_personal': None,
#             'key': '361d54e9-1ef0-4f68-9669-84f50e99a9ff',
#             'parent_id': 898489,
#             'parent_key': '899ea7d3-63ec-40f3-b7f8-4b37be6f5dca',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'ES007_OPE_CEO_ComunicacionesEuipo',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España/01. '
#                                     'Operaciones/ES007_OPE_CEO_ComunicacionesEuipo',
#             'id': 898491,
#             'is_personal': None,
#             'key': 'c1234a60-8b8b-4cd2-b5c6-a4e4e48f2072',
#             'parent_id': 61537,
#             'parent_key': '27a94834-663b-4866-b6c5-f26b7b948998',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': '01. Operaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/08. Colombia/01. Operaciones',
#             'id': 898493,
#             'is_personal': None,
#             'key': '3e4158b8-b2e1-490a-a59b-ee952ba60341',
#             'parent_id': 61526,
#             'parent_key': '642482c7-6ba6-4001-b14c-4974872a8fa8',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'CB001_OPE_APP_AvisoPlazosPatentes',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/08. Colombia/01. '
#                                     'Operaciones/CB001_OPE_APP_AvisoPlazosPatentes',
#             'id': 898494,
#             'is_personal': None,
#             'key': 'e492bd35-d2ae-4027-8276-fb5348a5f7e3',
#             'parent_id': 898493,
#             'parent_key': '3e4158b8-b2e1-490a-a59b-ee952ba60341',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'CL004_OPE_DNI_DescargaNotificacionesIdeterminados',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/06. Chile/01. '
#                                     'Operaciones/CL004_OPE_DNI_DescargaNotificacionesIdeterminados',
#             'id': 912392,
#             'is_personal': None,
#             'key': '8b52869d-217b-4c5f-ba2a-460e2c82e4e5',
#             'parent_id': 61532,
#             'parent_key': '4b373809-1bd6-4bb9-9713-f54038acb91c',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'MX006_OPE_PDT_PagoDeTasas',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/01. '
#                                     'Operaciones/MX006_OPE_PDT_PagoDeTasas',
#             'id': 1021003,
#             'is_personal': None,
#             'key': 'ef0441a3-7cb7-4b7d-9d1a-632cc0dac3aa',
#             'parent_id': 61541,
#             'parent_key': '5d71c7a1-a007-454e-8efd-831e1dd936bd',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'MX007_OPE_DPI_DescargaPatentesImpi_Solicitudes',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/01. '
#                                     'Operaciones/MX007_OPE_DPI_DescargaPatentesImpi_Solicitudes',
#             'id': 1031408,
#             'is_personal': None,
#             'key': 'ac51c907-b834-428b-978f-062a4e085d34',
#             'parent_id': 61541,
#             'parent_key': '5d71c7a1-a007-454e-8efd-831e1dd936bd',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'MX008_OPE_DPI_DescargaPatentesImpi_Notificaciones',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/04. Mexico/01. '
#                                     'Operaciones/MX008_OPE_DPI_DescargaPatentesImpi_Notificaciones',
#             'id': 1031409,
#             'is_personal': None,
#             'key': '2fcbb865-75d2-4f72-afae-981ec7ca2ff3',
#             'parent_id': 61541,
#             'parent_key': '5d71c7a1-a007-454e-8efd-831e1dd936bd',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Gaston II',
#             'display_name': 'PE004_OPE_GTM_GestionTitulosMarcas',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/09. Peru/01. '
#                                     'Operaciones/PE004_OPE_GTM_GestionTitulosMarcas',
#             'id': 1033713,
#             'is_personal': None,
#             'key': 'f8b4a08d-e18c-4e40-bc61-c3fe2f797803',
#             'parent_id': 61544,
#             'parent_key': '22d3bf1b-1860-4837-953f-2cf86bfd3119',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'ES008_OPE_VPE_ValidacionPatenteEuropea',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España/01. '
#                                     'Operaciones/ES008_OPE_VPE_ValidacionPatenteEuropea',
#             'id': 1034330,
#             'is_personal': None,
#             'key': '61e32919-4b3a-4e75-9685-9bf5f72e90ef',
#             'parent_id': 61537,
#             'parent_key': '27a94834-663b-4866-b6c5-f26b7b948998',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'CO007_OPE_TCT_TraspasoCarteras',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/01. '
#                                     'Operaciones/CO007_OPE_TCT_TraspasoCarteras',
#             'id': 1035404,
#             'is_personal': None,
#             'key': 'c378a176-68da-4766-9396-16a3197fab28',
#             'parent_id': 880909,
#             'parent_key': '22e6d2e9-bab6-4850-9b24-c459cbe340d2',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': 'Genaro 2',
#             'display_name': 'ES006_OPE_GTM_GestionTitulosMarcas',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/01. España/01. '
#                                     'Operaciones/ES006_OPE_GTM_GestionTitulosMarcas',
#             'id': 1036108,
#             'is_personal': None,
#             'key': '66ae02d8-659a-493f-86a7-b43bcc501c0c',
#             'parent_id': 61537,
#             'parent_key': '27a94834-663b-4866-b6c5-f26b7b948998',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'CB002_OPE_DNP_DescargaNotificacionesPatentes\u200b',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/08. Colombia/01. '
#                                     'Operaciones/CB002_OPE_DNP_DescargaNotificacionesPatentes\u200b',
#             'id': 1036206,
#             'is_personal': None,
#             'key': 'f24d319c-fc74-4090-a5fe-1fe16e71f7f3',
#             'parent_id': 898493,
#             'parent_key': '3e4158b8-b2e1-490a-a59b-ee952ba60341',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'CB003_OPE_APM_AvisoPlazosMarcas',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/08. Colombia/01. '
#                                     'Operaciones/CB003_OPE_APM_AvisoPlazosMarcas',
#             'id': 1036804,
#             'is_personal': None,
#             'key': '963bc696-641d-4d28-9b89-3d0e8a4ae73f',
#             'parent_id': 898493,
#             'parent_key': '3e4158b8-b2e1-490a-a59b-ee952ba60341',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'},
#            {'description': None,
#             'display_name': 'CO006_OPE_ADV_AvisoDeVencimientos',
#             'feed_type': 'Processes',
#             'folder_type': 'Standard',
#             'fully_qualified_name': 'RPA CoE/00. Corporativo/01. '
#                                     'Operaciones/CO006_OPE_ADV_AvisoDeVencimientos',
#             'id': 1091851,
#             'is_personal': None,
#             'key': '9d47476b-1016-472d-b9be-4f31f9402b17',
#             'parent_id': 880909,
#             'parent_key': '22e6d2e9-bab6-4850-9b24-c459cbe340d2',
#             'permission_model': 'FineGrained',
#             'provision_type': 'Automatic'}]}

# %%
for library in libs.value:
    logger.info(library.id)
    versions = uipclient_libraries.libraries_get_versions_by_packageid(package_id=library.id)
    for version in versions.value:
        try:
            logger.info(version.key)
            response = uipclient_libraries.libraries_download_package_by_key(key=version.key, _preload_content=False)
            if response.status == 200:
                file_name = f"{version.key}.nupkg"
                folder_name = library.id
                folder_base = "OUTPUT"
                # Open the local file in binary write mode
                local_folder_path = os.path.join(os.getcwd(), folder_base, folder_name)
                # Create the "OUTPUT" folder if it doesn't exist
                if not os.path.exists(local_folder_path):
                    os.makedirs(local_folder_path)
                # Combine the folder path and file name to get the full local file path
                local_file_path = os.path.join(local_folder_path, file_name)
                with open(local_file_path, 'wb') as local_file:
                    # Read data from the HTTPResponse and write it to the local file
                    local_file.write(response.data)          
                logger.info("File downloaded")  
            a = 5
        except Exception as e:
            logger.error("Error")
            logger.error(e)
# Out:
# 2023-10-18 17:02:29.682 | INFO     | __main__:<module>:2 - APIGES
# 2023-10-18 17:02:30.405 | INFO     | __main__:<module>:6 - Apiges:1.0.1
# 2023-10-18 17:03:40.557 | INFO     | __main__:<module>:22 - File downloaded
# 2023-10-18 17:03:40.558 | INFO     | __main__:<module>:6 - APIGES:1.0.4
# 2023-10-18 17:03:41.989 | INFO     | __main__:<module>:22 - File downloaded
# 2023-10-18 17:03:41.990 | INFO     | __main__:<module>:6 - APIGES:1.0.2
# 2023-10-18 17:03:43.174 | INFO     | __main__:<module>:22 - File downloaded
# 2023-10-18 17:03:43.175 | INFO     | __main__:<module>:2 - BlankLibrary
# 2023-10-18 17:03:43.318 | INFO     | __main__:<module>:6 - BlankLibrary:1.0.3
# 2023-10-18 17:03:44.528 | INFO     | __main__:<module>:22 - File downloaded
# 2023-10-18 17:03:44.529 | INFO     | __main__:<module>:2 - CLARKE_DEVOL_FWK_LIBRARY
# 2023-10-18 17:03:44.716 | INFO     | __main__:<module>:6 - CLARKE_DEVOL_FWK_LIBRARY:21.5.5
# 2023-10-18 17:03:44.926 | INFO     | __main__:<module>:22 - File downloaded
# 2023-10-18 17:03:44.928 | INFO     | __main__:<module>:6 - CLARKE_DEVOL_FWK_LIBRARY:21.5.4
# 2023-10-18 17:03:45.152 | INFO     | __main__:<module>:22 - File downloaded
# 2023-10-18 17:03:45.153 | INFO     | __main__:<module>:2 - CLARKEMODET_LIBRARY
# 2023-10-18 17:03:45.273 | INFO     | __main__:<module>:6 - CLARKEMODET_LIBRARY:1.0.40-alpha.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jmcaravaca/uipython/tests.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jmcaravaca/uipython/tests.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     local_file_path = os.path.join(local_folder_path, file_name)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jmcaravaca/uipython/tests.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>     with open(local_file_path, 'wb') as local_file:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jmcaravaca/uipython/tests.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>         # Read data from the HTTPResponse and write it to the local file
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jmcaravaca/uipython/tests.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>         local_file.write(response.data)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jmcaravaca/uipython/tests.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>     logger.info("File downloaded")
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jmcaravaca/uipython/tests.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> a = 5
#
# File ~/uipython/.venv/lib/python3.10/site-packages/urllib3/response.py:622, in HTTPResponse.data(self)
#     619     return self._body  # type: ignore[return-value]
#     621 if self._fp:
# --> 622     return self.read(cache_content=True)
#     624 return None
#
# File ~/uipython/.venv/lib/python3.10/site-packages/urllib3/response.py:879, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     876     if len(self._decoded_buffer) >= amt:
#     877         return self._decoded_buffer.get(amt)
# --> 879 data = self._raw_read(amt)
#     881 flush_decoder = amt is None or (amt != 0 and not data)
#     883 if not data and len(self._decoded_buffer) == 0:
#
# File ~/uipython/.venv/lib/python3.10/site-packages/urllib3/response.py:814, in HTTPResponse._raw_read(self, amt)
#     811 fp_closed = getattr(self._fp, "closed", False)
#     813 with self._error_catcher():
# --> 814     data = self._fp_read(amt) if not fp_closed else b""
#     815     if amt is not None and amt != 0 and not data:
#     816         # Platform-specific: Buggy versions of Python.
#     817         # Close the connection when no data is returned
#    (...)
#     822         # not properly close the connection in all cases. There is
#     823         # no harm in redundantly calling close.
#     824         self._fp.close()
#
# File ~/uipython/.venv/lib/python3.10/site-packages/urllib3/response.py:799, in HTTPResponse._fp_read(self, amt)
#     796     return buffer.getvalue()
#     797 else:
#     798     # StringIO doesn't like amt=None
# --> 799     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /usr/lib/python3.10/http/client.py:482, in HTTPResponse.read(self, amt)
#     480 else:
#     481     try:
# --> 482         s = self._safe_read(self.length)
#     483     except IncompleteRead:
#     484         self._close_conn()
#
# File /usr/lib/python3.10/http/client.py:631, in HTTPResponse._safe_read(self, amt)
#     624 def _safe_read(self, amt):
#     625     """Read the number of bytes requested.
#     626
#     627     This function should be used when <amt> bytes "should" be present for
#     628     reading. If the bytes are truly not available (due to EOF), then the
#     629     IncompleteRead exception can be used to detect the problem.
#     630     """
# --> 631     data = self.fp.read(amt)
#     632     if len(data) < amt:
#     633         raise IncompleteRead(data, amt-len(data))
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
